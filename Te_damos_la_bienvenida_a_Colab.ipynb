# %% [markdown]
# <a href="https://colab.research.google.com/github/Jairo1420/Mi-primer-proyecto-de-clase--Zscaner/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
numeros = [20, 30, 40]

# %%
edades = {10}

# %%
curso = []
curso = ["calculo","mecatronica", "fundamento de progrmacion"]

# %%
edades = [27,15,30,44,8]
for edades in edades:
  print (f"edad: {edades}")
# Out:
# edad: 27
# edad: 15
# edad: 30
# edad: 44
# edad: 8

# %%
matriz = [
    [1,2,3],
    [4,5,6]
  ]
print(matriz)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
matriz = []
matriz.append([1,2,3])
matriz.append([4,5,6])
print(matriz)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
matriz = [[i+j*3+1 for i in range (3)]for j in range (2)]
print(matriz)
# Out:
# [[1, 2, 3], [4, 5, 6]]
